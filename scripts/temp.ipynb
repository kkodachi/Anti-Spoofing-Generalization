# %%
import os
from pathlib import Path
import torch

print(Path())
print(os.getcwd())

file_path = Path("/scratch1/kodachi/project/data/wav16")

if file_path.is_dir():
    print("The dir exists.")
else:
    print("DNE")

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(DEVICE)
